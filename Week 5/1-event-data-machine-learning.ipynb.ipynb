# %% [markdown]
# # 축구 데이터 분석 4주차

# %%
# !git clone https://github.com/narame7/UOS-FootballDataAnalytics-Tutorial.git
# Out:
# fatal: destination path 'UOS-FootballDataAnalytics-Tutorial' already exists and is not an empty directory.

# %%
# !ls
# Out:
# sample_data  UOS-FootballDataAnalytics-Tutorial

# %%
# %cd 'UOS-FootballDataAnalytics-Tutorial/Week 4'
# Out:
# /content/UOS-FootballDataAnalytics-Tutorial/Week 4

# %%
# !unzip data.zip -d data/ #압축 해제
# Out:
# Archive:  data.zip
# replace data/__MACOSX/._wyscout_data? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plot_utils import get_pitch_layout

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score

# %%
from data_utils import refine_and_save_events
from plot_utils import draw_pitch

# %%
DATA_DIR = os.path.join(".", "data", "wyscout_data")
DATA_DIR
# Out:
# './data/wyscout_data'

# %% [markdown]
# ## 이벤트 데이터 준비

# %%
# refine_and_save_events(dataset_name='England')
# refine_and_save_events(dataset_name='Spain')
# refine_and_save_events(dataset_name='Italy')
# refine_and_save_events(dataset_name='Germany')
# refine_and_save_events(dataset_name='France')
# refine_and_save_events(dataset_name='European_Championship')
# refine_and_save_events(dataset_name='World_Cup')

# %%
match_events = pd.read_pickle(os.path.join(DATA_DIR, 'refined_events', 'England', '2499719.pkl'))
match_events
# Out:
#      match_id   event_id period      time team_id       team_name player_id  \
# 0     2499719  177959171     1H     2.759    1609         Arsenal     25413
# 1     2499719  177959172     1H     4.947    1609         Arsenal    370224
# 2     2499719  177959173     1H     6.542    1609         Arsenal      3319
# 3     2499719  177959174     1H     8.143    1609         Arsenal    120339
# 4     2499719  177959175     1H    10.302    1609         Arsenal    167145
# ...       ...        ...    ...       ...     ...             ...       ...
# 1775  2499719  177961040     2H  2992.492    1631  Leicester City      8480
# 1776  2499719  177961035     2H  2994.901    1609         Arsenal     49876
# 1777  2499719  177961036     2H  2997.086    1609         Arsenal      7870
# 1778  2499719  177961041     2H  2998.964    1631  Leicester City         0
# 1779  2499719  177961042     2H  3006.647    1631  Leicester City      8480
#
#          player_name    event_type         sub_event_type  \
# 0       A. Lacazette          Pass            Simple pass
# 1         R. Holding          Pass              High pass
# 2            M. Özil          Pass              Head pass
# 3     Mohamed Elneny          Pass              Head pass
# 4           Bellerín          Pass            Simple pass
# ...              ...           ...                    ...
# 1775   K. Schmeichel          Pass                 Launch
# 1776        G. Xhaka          Pass              Head pass
# 1777       A. Ramsey          Shot                   Shot
# 1778             NaN  Interruption  Ball out of the field
# 1779   K. Schmeichel     Free kick              Goal kick
#
#                                                    tags  start_x  start_y  \
# 0                                            [Accurate]    50.96    34.68
# 1                                            [Accurate]    32.24    14.96
# 2                                            [Accurate]    53.04    17.00
# 3                                            [Accurate]    36.40    19.72
# 4                                            [Accurate]    42.64     3.40
# ...                                                 ...      ...      ...
# 1775                                     [Not accurate]     7.28    31.96
# 1776                                         [Accurate]    56.16    33.32
# 1777  [Right foot, Opportunity, Position: Out high r...    75.92    28.56
# 1778                                                 []     3.12    35.36
# 1779                                                 []     0.00    34.00
#
#        end_x  end_y
# 0      32.24  14.96
# 1      53.04  17.00
# 2      36.40  19.72
# 3      42.64   3.40
# 4      74.88   8.16
# ...      ...    ...
# 1775   47.84  34.68
# 1776   75.92  28.56
# 1777  104.00  34.00
# 1778     NaN    NaN
# 1779     NaN    NaN
#
# [1780 rows x 15 columns]

# %%
competitions = [x for x in os.listdir(os.path.join(DATA_DIR, 'refined_events'))]
competitions
# Out:
# ['Germany',
#  'England',
#  'France',
#  'World_Cup',
#  'European_Championship',
#  'Italy',
#  'Spain']

# %%
match_events_list = []
for competition_name in competitions:
    matches_path = os.path.join(DATA_DIR, "matches", f"matches_{competition_name}.json")
    with open(matches_path) as json_data:
        matches = json.load(json_data)
    match_df = pd.DataFrame(matches)

    for match_id in tqdm(match_df.wyId, desc=f"{competition_name} precessing...."):
        match_events = pd.read_pickle(os.path.join(DATA_DIR, 'refined_events', competition_name, f'{match_id}.pkl'))
        match_events['competition_name'] = competition_name
        match_events_list.append(match_events)

events = pd.concat(match_events_list, ignore_index=True)
events
# Out:
# Germany precessing....:   0%|          | 0/306 [00:00<?, ?it/s]
# England precessing....:   0%|          | 0/380 [00:00<?, ?it/s]
# France precessing....:   0%|          | 0/380 [00:00<?, ?it/s]
# World_Cup precessing....:   0%|          | 0/64 [00:00<?, ?it/s]
# European_Championship precessing....:   0%|          | 0/51 [00:00<?, ?it/s]
# Italy precessing....:   0%|          | 0/380 [00:00<?, ?it/s]
# Spain precessing....:   0%|          | 0/380 [00:00<?, ?it/s]
#         match_id   event_id period      time team_id         team_name  \
# 0        2517036  251207291     1H     6.079    2444    Bayern München
# 1        2517036  251207292     1H     8.106    2444    Bayern München
# 2        2517036  251207293     1H    10.012    2444    Bayern München
# 3        2517036  251207294     1H    11.942    2444    Bayern München
# 4        2517036  251207295     1H    13.466    2444    Bayern München
# ...          ...        ...    ...       ...     ...               ...
# 3273243  2565557  179895927     2H  2845.945     696  Deportivo Alavés
# 3273244  2565557  179895738     2H  2847.985     712           Leganés
# 3273245  2565557  179895928     2H  2847.985     696  Deportivo Alavés
# 3273246  2565557  179895929     2H  2849.923     696  Deportivo Alavés
# 3273247  2565557  179895742     2H  2883.957     712           Leganés
#
#         player_id       player_name          event_type  \
# 0          209091        C. Tolisso                Pass
# 1           70096      J. Rodríguez                Pass
# 2            3345  Thiago Alcântara                Pass
# 3           14795        M. Hummels                Pass
# 4           70096      J. Rodríguez  Others on the ball
# ...           ...               ...                 ...
# 3273243    114055      Óscar Romero                Duel
# 3273244    169002        Diego Rico                Duel
# 3273245    114055      Óscar Romero                Duel
# 3273246    114055      Óscar Romero                Foul
# 3273247         0               NaN           Free kick
#
#                 sub_event_type                                tags  start_x  \
# 0                  Simple pass                          [Accurate]    52.00
# 1                  Simple pass                          [Accurate]    41.60
# 2                  Simple pass                          [Accurate]    34.32
# 3                  Simple pass                          [Accurate]    24.96
# 4                        Touch                                  []    35.36
# ...                        ...                                 ...      ...
# 3273243  Ground attacking duel  [Take on left, Lost, Not accurate]    92.56
# 3273244  Ground attacking duel                     [Won, Accurate]     8.32
# 3273245  Ground defending duel                [Lost, Not accurate]    95.68
# 3273246                   Foul                                  []    96.72
# 3273247              Free kick                      [Not accurate]     4.16
#
#          start_y  end_x  end_y competition_name
# 0          33.32  41.60  42.16          Germany
# 1          42.16  34.32  30.60          Germany
# 2          30.60  24.96  41.48          Germany
# 3          41.48  35.36  51.68          Germany
# 4          51.68  45.76  42.84          Germany
# ...          ...    ...    ...              ...
# 3273243     2.72  95.68   5.44            Spain
# 3273244    62.56   7.28  63.24            Spain
# 3273245     5.44  96.72   4.76            Spain
# 3273246     4.76    NaN    NaN            Spain
# 3273247    31.96    NaN    NaN            Spain
#
# [3273248 rows x 16 columns]

# %%
matches_path = os.path.join(DATA_DIR, "matches", f"matches_World_Cup.json")
with open(matches_path) as json_data:
    matches = json.load(json_data)

match_df = pd.DataFrame(matches)
match_df["team_names"] = match_df.label.apply(lambda l: l.split(', ')[0])
match_df["team1_name"] = match_df.team_names.apply(
    lambda t: t.encode('ascii', 'strict').decode('unicode-escape').split(' - ')[0]
)
match_df["team2_name"] = match_df.team_names.apply(
    lambda t: t.encode('ascii', 'strict').decode('unicode-escape').split(' - ')[1]
)

match_df
# Out:
#     status  roundId  gameweek  \
# 0   Played  4165368         0
# 1   Played  4165367         0
# 2   Played  4165366         0
# 3   Played  4165366         0
# 4   Played  4165365         0
# ..     ...      ...       ...
# 59  Played  4165363         1
# 60  Played  4165363         1
# 61  Played  4165363         1
# 62  Played  4165363         1
# 63  Played  4165363         1
#
#                                             teamsData  seasonId  \
# 0   {'9598': {'scoreET': 0, 'coachId': 122788, 'si...     10078
# 1   {'2413': {'scoreET': 0, 'coachId': 276858, 'si...     10078
# 2   {'2413': {'scoreET': 1, 'coachId': 276858, 'si...     10078
# 3   {'5629': {'scoreET': 0, 'coachId': 8605, 'side...     10078
# 4   {'14358': {'scoreET': 2, 'coachId': 264893, 's...     10078
# ..                                                ...       ...
# 59  {'8493': {'scoreET': 0, 'coachId': 134090, 'si...     10078
# 60  {'9905': {'scoreET': 0, 'coachId': 137521, 'si...     10078
# 61  {'10840': {'scoreET': 0, 'coachId': 136612, 's...     10078
# 62  {'16129': {'scoreET': 0, 'coachId': 33204, 'si...     10078
# 63  {'14358': {'scoreET': 0, 'coachId': 264893, 's...     10078
#
#                 dateutc  winner                         venue     wyId  \
# 0   2018-07-15 15:00:00    4418  Olimpiyskiy stadion Luzhniki  2058017
# 1   2018-07-14 14:00:00    5629           Stadion Krestovskyi  2058016
# 2   2018-07-11 18:00:00    9598  Olimpiyskiy stadion Luzhniki  2058015
# 3   2018-07-10 18:00:00    4418           Stadion Krestovskyi  2058014
# 4   2018-07-07 18:00:00    9598     Olimpiyskiy Stadion Fisht  2058012
# ..                  ...     ...                           ...      ...
# 59  2018-06-16 10:00:00    4418                  Kazan' Arena  2057966
# 60  2018-06-15 18:00:00       0     Olimpiyskiy Stadion Fisht  2057960
# 61  2018-06-15 15:00:00   10840           Stadion Krestovskyi  2057961
# 62  2018-06-15 12:00:00   15670           Stadion Central'nyj  2057955
# 63  2018-06-14 15:00:00   14358  Olimpiyskiy stadion Luzhniki  2057954
#
#                            label                                date  \
# 0        France - Croatia, 4 - 2   July 15, 2018 at 5:00:00 PM GMT+2
# 1       Belgium - England, 2 - 0   July 14, 2018 at 4:00:00 PM GMT+2
# 2   Croatia - England, 2 - 1 (E)   July 11, 2018 at 8:00:00 PM GMT+2
# 3        France - Belgium, 1 - 0   July 10, 2018 at 8:00:00 PM GMT+2
# 4    Russia - Croatia, 2 - 2 (P)    July 7, 2018 at 8:00:00 PM GMT+2
# ..                           ...                                 ...
# 59     France - Australia, 2 - 1  June 16, 2018 at 12:00:00 PM GMT+2
# 60       Portugal - Spain, 3 - 3   June 15, 2018 at 8:00:00 PM GMT+2
# 61         Morocco - Iran, 0 - 1   June 15, 2018 at 5:00:00 PM GMT+2
# 62        Egypt - Uruguay, 0 - 1   June 15, 2018 at 2:00:00 PM GMT+2
# 63  Russia - Saudi Arabia, 5 - 0   June 14, 2018 at 5:00:00 PM GMT+2
#
#    groupName                                           referees   duration  \
# 0             [{'refereeId': 378051, 'role': 'referee'}, {'r...    Regular
# 1             [{'refereeId': 380599, 'role': 'referee'}, {'r...    Regular
# 2             [{'refereeId': 384995, 'role': 'referee'}, {'r...  ExtraTime
# 3             [{'refereeId': 378232, 'role': 'referee'}, {'r...    Regular
# 4             [{'refereeId': 378204, 'role': 'referee'}, {'r...  Penalties
# ..       ...                                                ...        ...
# 59   Group C  [{'refereeId': 378232, 'role': 'referee'}, {'r...    Regular
# 60   Group B  [{'refereeId': 377206, 'role': 'referee'}, {'r...    Regular
# 61   Group B  [{'refereeId': 384995, 'role': 'referee'}, {'r...    Regular
# 62   Group A  [{'refereeId': 377215, 'role': 'referee'}, {'r...    Regular
# 63   Group A  [{'refereeId': 378051, 'role': 'referee'}, {'r...    Regular
#
#     competitionId             team_names team1_name    team2_name
# 0              28       France - Croatia     France       Croatia
# 1              28      Belgium - England    Belgium       England
# 2              28      Croatia - England    Croatia       England
# 3              28       France - Belgium     France       Belgium
# 4              28       Russia - Croatia     Russia       Croatia
# ..            ...                    ...        ...           ...
# 59             28     France - Australia     France     Australia
# 60             28       Portugal - Spain   Portugal         Spain
# 61             28         Morocco - Iran    Morocco          Iran
# 62             28        Egypt - Uruguay      Egypt       Uruguay
# 63             28  Russia - Saudi Arabia     Russia  Saudi Arabia
#
# [64 rows x 18 columns]

# %% [markdown]
# ### 슈팅 추출

# %% [markdown]
# ##### (1) 슈팅 데이터 필터링

# %%
shots = events[
    (events['event_type'] == 'Shot') | (events['sub_event_type'].isin(['Free kick shot', 'Penalty']))
].reset_index(drop=True)

shots
# Out:
#       match_id   event_id period      time team_id         team_name  \
# 0      2517036  251207326     1H    75.347    2444    Bayern München
# 1      2517036  251207376     1H   184.082    2444    Bayern München
# 2      2517036  251207486     1H   296.845    2445         Stuttgart
# 3      2517036  251207570     1H    494.65    2445         Stuttgart
# 4      2517036  251207760     1H   1230.73    2444    Bayern München
# ...        ...        ...    ...       ...     ...               ...
# 45940  2565557  179895765     2H  1574.021     696  Deportivo Alavés
# 45941  2565557  179895816     2H  1954.716     696  Deportivo Alavés
# 45942  2565557  179895846     2H  2209.612     696  Deportivo Alavés
# 45943  2565557  179895569     2H  2338.754     712           Leganés
# 45944  2565557  179895571     2H  2340.488     712           Leganés
#
#       player_id     player_name event_type sub_event_type  \
# 0         70096    J. Rodríguez       Shot           Shot
# 1         14817  R. Lewandowski       Shot           Shot
# 2         14845      D. Ginczek       Shot           Shot
# 3        349099      O. Mangala       Shot           Shot
# 4        209091      C. Tolisso       Shot           Shot
# ...         ...             ...        ...            ...
# 45940    208694     Rodrigo Ely       Shot           Shot
# 45941    114055    Óscar Romero       Shot           Shot
# 45942    226005          Burgui       Shot           Shot
# 45943      3934      N. El Zhar       Shot           Shot
# 45944      5481        Guerrero       Shot           Shot
#
#                                                     tags  start_x  start_y  \
# 0                     [Left foot, Blocked, Not accurate]    78.00    34.68
# 1      [Left foot, Position: Out low right, Not accur...    84.24    29.92
# 2      [Goal, Right foot, Opportunity, Position: Goal...    99.84    36.04
# 3      [Right foot, Opportunity, Position: Goal cente...    79.04    26.52
# 4      [Goal, Right foot, Opportunity, Position: Goal...    92.56    27.88
# ...                                                  ...      ...      ...
# 45940  [Head/body, Opportunity, Position: Goal center...    93.60    46.24
# 45941  [Left foot, Opportunity, Position: Goal center...    82.16    44.20
# 45942  [Right foot, Opportunity, Position: Post high ...    72.80    32.64
# 45943    [Left foot, Blocked, Opportunity, Not accurate]    92.56    22.44
# 45944  [Head/body, Interception, Opportunity, Positio...    92.56    31.28
#
#         end_x  end_y competition_name
# 0       92.56  29.92          Germany
# 1      104.00  34.00          Germany
# 2      104.00  34.00          Germany
# 3      104.00  34.00          Germany
# 4      104.00  34.00          Germany
# ...       ...    ...              ...
# 45940  104.00  34.00            Spain
# 45941  104.00  34.00            Spain
# 45942  104.00  34.00            Spain
# 45943   92.56  31.28            Spain
# 45944  101.92  46.92            Spain
#
# [45945 rows x 16 columns]

# %% [markdown]
# ##### (2) 슈팅 데이터 시각화

# %%
match_id = 2057987
match_shots = shots[shots['match_id'] == match_id]
team1_name, team2_name = match_df[match_df['wyId'] == match_id][['team1_name', 'team2_name']].values[0]

match_shots_success = match_shots[match_shots['tags'].apply(lambda x: 'Goal' in x)]
match_shots_failed = match_shots[match_shots['tags'].apply(lambda x: 'Goal' not in x)]

team1_goals = match_shots_success[match_shots_success['team_name'] == team1_name]
team2_goals = match_shots_success[match_shots_success['team_name'] == team2_name]

team1_not_goals = match_shots_failed[match_shots_failed['team_name'] == team1_name]
team2_not_goals = match_shots_failed[match_shots_failed['team_name'] == team2_name]


team1_goal_trace = go.Scatter(
    x=team1_goals['start_x'],
    y=team1_goals['start_y'],
    name=f"{team1_name}: success shot",
    mode='markers',
    marker=dict(color='red')
)

team2_goal_trace = go.Scatter(
    x=team2_goals['start_x'],
    y=team2_goals['start_y'],
    name=f"{team2_name}: success shot",
    mode='markers',
    marker=dict(color='blue')
)

team1_not_goal_trace = go.Scatter(
    x=team1_not_goals['start_x'],
    y=team1_not_goals['start_y'],
    name=f"{team1_name}: failed shot",
    mode='markers',
    marker=dict(color='green')
)

team2_not_goal_trace = go.Scatter(
    x=team2_not_goals['start_x'],
    y=team2_not_goals['start_y'],
    name=f"{team2_name}: failed shot",
    mode='markers',
    marker=dict(color='purple')
)

fig = go.Figure(data=[team1_not_goal_trace, team2_not_goal_trace, team1_goal_trace, team2_goal_trace], layout=get_pitch_layout("Shot"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1a0fe8ff-213b-430e-b0e2-132c2952729f" class="plotly-graph-div" style="height:600px; width:825px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a0fe8ff-213b-430e-b0e2-132c2952729f")) {                    Plotly.newPlot(                        "1a0fe8ff-213b-430e-b0e2-132c2952729f",                        [{"marker":{"color":"green"},"mode":"markers","name":"Korea Republic: failed shot","x":[90.48,91.52000000000001,82.16,92.56,75.92,100.88000000000001,81.12,83.2,91.52000000000001,89.44,86.32000000000001,90.48,83.2,73.84,75.92,78.0],"y":[22.44,22.44,26.520000000000003,30.6,34.0,47.6,23.12,40.120000000000005,25.16,9.520000000000001,55.760000000000005,36.04,34.68,27.200000000000003,27.200000000000003,35.36],"type":"scatter"},{"marker":{"color":"purple"},"mode":"markers","name":"Mexico: failed shot","x":[91.52000000000001,89.44,91.52000000000001,81.12,79.04,81.12,87.36,82.16,82.16,81.12],"y":[27.880000000000003,28.560000000000002,48.28,50.32,31.28,37.400000000000006,40.800000000000004,38.080000000000005,19.040000000000006,29.92],"type":"scatter"},{"marker":{"color":"red"},"mode":"markers","name":"Korea Republic: success shot","x":[80.08],"y":[17.68],"type":"scatter"},{"marker":{"color":"blue"},"mode":"markers","name":"Mexico: success shot","x":[92.56,94.64],"y":[32.64,43.52],"type":"scatter"}],                        {"autosize":false,"height":600,"hovermode":"closest","plot_bgcolor":"rgb(255, 255, 255)","shapes":[{"line":{"color":"black"},"type":"circle","x0":41.6,"x1":62.4,"xref":"x","y0":23.799999999999997,"y1":44.2,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":0,"x1":20.8,"xref":"x","y0":11.22,"y1":11.22,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":20.8,"x1":20.8,"xref":"x","y0":11.22,"y1":56.78,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":20.8,"x1":0,"xref":"x","y0":56.78,"y1":56.78,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":104,"x1":83.2,"xref":"x","y0":11.22,"y1":11.22,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":83.2,"x1":83.2,"xref":"x","y0":11.22,"y1":56.78,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":83.2,"x1":104,"xref":"x","y0":56.78,"y1":56.78,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":0,"x1":5.72,"xref":"x","y0":23.799999999999997,"y1":23.799999999999997,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":5.72,"x1":5.72,"xref":"x","y0":23.799999999999997,"y1":44.2,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":5.72,"x1":0,"xref":"x","y0":44.2,"y1":44.2,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":104,"x1":98.28,"xref":"x","y0":23.799999999999997,"y1":23.799999999999997,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":98.28,"x1":98.28,"xref":"x","y0":23.799999999999997,"y1":44.2,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":98.28,"x1":104,"xref":"x","y0":44.2,"y1":44.2,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":52.0,"x1":52.0,"xref":"x","y0":68,"y1":0,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":0,"x1":0,"xref":"x","y0":0,"y1":68,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":104,"x1":104,"xref":"x","y0":0,"y1":68,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":0,"x1":104,"xref":"x","y0":68,"y1":68,"yref":"y"},{"line":{"color":"black"},"type":"line","x0":0,"x1":104,"xref":"x","y0":0,"y1":0,"yref":"y"}],"title":{"text":"Shot"},"width":825,"xaxis":{"range":[0,104],"showgrid":false,"showticklabels":false},"yaxis":{"range":[0,68],"showgrid":false,"showticklabels":false},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c ...

# %% [markdown]
# ## 기계학습: xG(Expected Goal)
# ### 슈팅별 특징 추출

# %%
#x,y좌표는 왼쪽 아래가 (0,0)으로 설정되어있음
#상대팀골대중앙을 기준으로 (x,y)를 설정해야하므로
#(104-start_x , start_y-34)로 설정함
shot_features = pd.DataFrame(index=shots.index)
shot_features['x'] = 104 - shots['start_x']
shot_features['y'] = shots['start_y'] - 34
shot_features
# Out:
#            x      y
# 0      26.00   0.68
# 1      19.76  -4.08
# 2       4.16   2.04
# 3      24.96  -7.48
# 4      11.44  -6.12
# ...      ...    ...
# 45940  10.40  12.24
# 45941  21.84  10.20
# 45942  31.20  -1.36
# 45943  11.44 -11.56
# 45944  11.44  -2.72
#
# [45945 rows x 2 columns]

# %% [markdown]
# ##### (1) 슈팅 위치 및 거리 계산

# %%
#피타고라스 거리 = norm2을 적용함
shot_features['distance'] = shot_features[['x', 'y']].apply(np.linalg.norm, axis=1)
shot_features
# Out:
#            x      y   distance
# 0      26.00   0.68  26.008891
# 1      19.76  -4.08  20.176818
# 2       4.16   2.04   4.633271
# 3      24.96  -7.48  26.056707
# 4      11.44  -6.12  12.974128
# ...      ...    ...        ...
# 45940  10.40  12.24  16.061681
# 45941  21.84  10.20  24.104473
# 45942  31.20  -1.36  31.229627
# 45943  11.44 -11.56  16.263677
# 45944  11.44  -2.72  11.758912
#
# [45945 rows x 3 columns]

# %% [markdown]
# ##### (2) 슈팅 각도 계산
#
# 골대너비 w = 7.32m $\\$
#
# 해당과정에서 tan를 계산하면 됨
#
# $$\\theta = \arctan\left(\frac{w \times x}{x^2+y^2-(w/2)^2}\right)$$

# %%
x = shot_features['x']
y = shot_features['y']
goal_width = 7.32
angles = np.arctan((goal_width * x) / (x ** 2 + y ** 2 - (goal_width / 2) ** 2)) * 180 / np.pi
shot_features['angle'] = np.where(angles >= 0, angles, angles + 180)
shot_features
# Out:
#            x      y   distance      angle
# 0      26.00   0.68  26.008891  16.015062
# 1      19.76  -4.08  20.176818  20.172657
# 2       4.16   2.04   4.633271  75.154201
# 3      24.96  -7.48  26.056707  15.350572
# 4      11.44  -6.12  12.974128  28.391175
# ...      ...    ...        ...        ...
# 45940  10.40  12.24  16.061681  17.289149
# 45941  21.84  10.20  24.104473  15.729482
# 45942  31.20  -1.36  31.229627  13.356507
# 45943  11.44 -11.56  16.263677  18.442533
# 45944  11.44  -2.72  11.758912  33.845389
#
# [45945 rows x 4 columns]

# %% [markdown]
# ##### (3) 슈팅 유형 및 득점 여부 추출

# %%
shot_features['freekick'] = (shots['event_type'] == 'Free kick').astype(int)
shot_features['header'] = shots['tags'].apply(lambda x: 'Head/body' in x).astype(int)
shot_features['goal'] = shots['tags'].apply(lambda x: 'Goal' in x).astype(int)
shot_features
# Out:
#            x      y   distance      angle  freekick  header  goal
# 0      26.00   0.68  26.008891  16.015062         0       0     0
# 1      19.76  -4.08  20.176818  20.172657         0       0     0
# 2       4.16   2.04   4.633271  75.154201         0       0     1
# 3      24.96  -7.48  26.056707  15.350572         0       0     0
# 4      11.44  -6.12  12.974128  28.391175         0       0     1
# ...      ...    ...        ...        ...       ...     ...   ...
# 45940  10.40  12.24  16.061681  17.289149         0       1     0
# 45941  21.84  10.20  24.104473  15.729482         0       0     0
# 45942  31.20  -1.36  31.229627  13.356507         0       0     0
# 45943  11.44 -11.56  16.263677  18.442533         0       0     0
# 45944  11.44  -2.72  11.758912  33.845389         0       1     0
#
# [45945 rows x 7 columns]

# %% [markdown]
# #### xG 모델 학습

# %%
def train(df, model_type="Logistic Regression", features=['distance'], test_size=0.1):
    """
    주어진 데이터프레임과 feature 목록을 사용하여 다양한 분류 모델을 학습하고 평가합니다.

    Args:
        df (pd.DataFrame): 전체 데이터셋 (shot_features)
        features (list): 모델 학습에 사용할 feature 이름들의 리스트
        test_size (float): 테스트 데이터셋의 비율
        random_state (int): 결과 재현을 위한 시드값
    """
    # 1. Feature(X)와 Label(y) 분리
    X = df[features]
    y = df['goal']

    # 2. 학습 데이터와 테스트 데이터 분리
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, stratify=y)

    # 3. 데이터 스케일링 (거리 기반 모델 등을 위해)
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # 4. 실험할 모델 목록 정의
    model_dict = {
        'Logistic Regression': LogisticRegression(max_iter=1000),
        'K-Nearest Neighbors': KNeighborsClassifier(n_neighbors=7),
        'Decision Tree': DecisionTreeClassifier(max_depth=5, min_samples_split=20),
        'Random Forest': RandomForestClassifier(n_estimators=150, max_depth=7)
    }

    # 5. 각 모델별 학습 및 평가
    model = model_dict[model_type]
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)
    y_pred_proba = model.predict_proba(X_test_scaled)[:, 1]

    accuracy = accuracy_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred_proba)

    # 6. 결과 출력
    print(f"--- Model: {model}, Features: {features} ---")
    print(f"  Accuracy = {accuracy:.4f}")
    print(f"  ROC AUC = {roc_auc:.4f}")
    print("-" * 30)

    preds = pd.concat([pd.DataFrame(X_test, columns=features).reset_index(drop=True),
                      pd.DataFrame(y_test, columns=["goal"]).reset_index(drop=True),
                      pd.DataFrame(y_pred_proba, columns=["xg"]).reset_index(drop=True)],
                      axis=1, ignore_index=False)

    return model, preds

# %% [markdown]
# - 슈팅 거리 구간별 득점 확률 산출

# %%
features_1 = ['distance']
_, preds1 = train(shot_features, model_type="Logistic Regression", features=features_1)
preds1
# Out:
# --- Model: LogisticRegression(max_iter=1000), Features: ['distance'] ---
#   Accuracy = 0.8888
#   ROC AUC = 0.7453
# ------------------------------
#        distance  goal        xg
# 0     28.899855     0  0.019498
# 1     20.844414     0  0.057522
# 2     24.867778     0  0.033685
# 3     28.756217     0  0.019884
# 4     28.504287     0  0.020579
# ...         ...   ...       ...
# 4590  21.089106     0  0.055703
# 4591  26.713892     0  0.026251
# 4592  19.923694     0  0.064878
# 4593  32.644534     0  0.011669
# 4594  13.219138     0  0.149973
#
# [4595 rows x 3 columns]

# %%
#슛팅거리는 1m당 득점확률로 산출
bins = np.arange(0, 50, 1) + 1
dist_cats = pd.cut(preds1['distance'], bins, right=False)
goal_per_dist = preds1.groupby(dist_cats)['goal'].mean()
xg_per_dist = preds1.groupby(dist_cats)['xg'].mean()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.scatter(bins[:-1], goal_per_dist.values, s=50)
ax1.set_title("Actual Goal Probability")
ax1.set_xlabel("Shot distance (m)")
ax1.set_ylabel("Probability of a shot scored")
ax1.grid(True, linestyle='--', alpha=0.6)

ax2.scatter(bins[:-1], xg_per_dist.values, s=50, color='orange')
ax2.set_title("Expected Goal (xG) Probability")
ax2.set_xlabel("Shot distance (m)")
ax2.set_ylabel("Predicted Probability (xG)")
ax2.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-984943168.py:4: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /tmp/ipython-input-984943168.py:5: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %% [markdown]
# - 슈팅 각도 구간별 득점 확률 산출

# %%
features_2 = ['angle']
_, preds2 = train(shot_features, model_type="Logistic Regression", features=features_2)
preds2
# Out:
# --- Model: LogisticRegression(max_iter=1000), Features: ['angle'] ---
#   Accuracy = 0.8927
#   ROC AUC = 0.7679
# ------------------------------
#           angle  goal        xg
# 0     14.708783     0  0.059156
# 1     20.836980     0  0.080284
# 2     20.342820     0  0.078352
# 3     29.148216     0  0.119884
# 4     29.932171     0  0.124384
# ...         ...   ...       ...
# 4590  14.797756     0  0.059422
# 4591  69.664922     1  0.543814
# 4592  19.655493     0  0.075735
# 4593  19.270113     0  0.074303
# 4594   9.386115     0  0.045150
#
# [4595 rows x 3 columns]

# %%
bins = np.arange(0, 50, 1) + 1
dist_cats = pd.cut(preds2['angle'], bins, right=False)
goal_per_angle = preds2.groupby(dist_cats)['goal'].mean()
xg_per_angle = preds2.groupby(dist_cats)['xg'].mean()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.scatter(bins[:-1], goal_per_angle.values, s=50)
ax1.set_title("Actual Goal Probability")
ax1.set_xlabel("Shot Angle (degrees)")
ax1.set_ylabel("Probability of a shot scored")
ax1.grid(True, linestyle='--', alpha=0.6)

ax2.scatter(bins[:-1], xg_per_angle.values, s=50, color='orange')
ax2.set_title("Expected Goal (xG) Probability")
ax2.set_xlabel("Shot Angle (degrees)")
ax2.set_ylabel("Predicted Probability (xG)")
ax2.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-137362593.py:3: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /tmp/ipython-input-137362593.py:4: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
features_3 = ['x', 'y', 'distance', 'angle', 'freekick', 'header']
model, preds3 = train(shot_features, model_type="Logistic Regression", features=features_3)
preds3
# Out:
# --- Model: LogisticRegression(max_iter=1000), Features: ['x', 'y', 'distance', 'angle', 'freekick', 'header'] ---
#   Accuracy = 0.8990
#   ROC AUC = 0.7919
# ------------------------------
#           x      y   distance      angle  freekick  header  goal        xg
# 0     11.44   0.68  11.460192  35.375758         1       0     1  0.570988
# 1     27.04  -7.48  28.055516  14.349704         0       0     0  0.023634
# 2     29.12   0.68  29.127938  14.319911         0       0     0  0.021954
# 3      5.20   8.16   9.676032  25.381346         0       0     0  0.190703
# 4     12.48  -1.36  12.553884  32.354290         0       1     1  0.075351
# ...     ...    ...        ...        ...       ...     ...   ...       ...
# 4590  19.76  -6.80  20.897311  18.865408         0       0     0  0.056978
# 4591   8.32   0.00   8.320000  47.489757         0       1     0  0.163988
# 4592  14.56  19.72  24.512691  10.282688         0       1     0  0.009436
# 4593   6.24   8.84  10.820499  23.774608         0       0     0  0.165618
# 4594   7.28  -0.68   7.311689  53.062727         0       0     1  0.415285
#
# [4595 rows x 8 columns]

# %% [markdown]
# ##### xG 히트맵 시각화

# %%
shot_grid = []
m = 50
n = 64

for x_idx in range(m):
    for y_idx in range(n):
        x = (x_idx + 0.5) * 52 / m
        y = (y_idx + 0.5) * 68 / n - 34
        shot_grid.append({'x_idx': x_idx, 'y_idx': y_idx, 'x': x, 'y': y})

shot_grid = pd.DataFrame(shot_grid)
shot_grid['distance'] = shot_grid[['x', 'y']].apply(np.linalg.norm, axis=1)

x = shot_grid['x']
y = shot_grid['y']
goal_width = 7.32
angles = np.arctan((goal_width * x) / (x ** 2 + y ** 2 - (goal_width / 2) ** 2))
shot_grid['angle'] = np.where(angles >= 0, angles, angles + np.pi) * 180 / np.pi

#구역별 xg를 계산하기위해 프리킥,헤딩은 제외
shot_grid['freekick'] = 0
shot_grid['header'] = 0


shot_grid['xg'] = model.predict_proba(shot_grid[features_3])[:, 1]
shot_grid
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning:
#
# X has feature names, but LogisticRegression was fitted without feature names
#       x_idx  y_idx      x         y   distance     angle  freekick  header  \
# 0         0      0   0.52 -33.46875  33.472789  0.197004         0       0
# 1         0      1   0.52 -32.40625  32.410422  0.210300         0       0
# 2         0      2   0.52 -31.34375  31.348063  0.224996         0       0
# 3         0      3   0.52 -30.28125  30.285714  0.241295         0       0
# 4         0      4   0.52 -29.21875  29.223377  0.259442         0       0
# ...     ...    ...    ...       ...        ...       ...       ...     ...
# 3195     49     59  51.48  29.21875  59.193967  6.161722         0       0
# 3196     49     60  51.48  30.28125  59.725577  6.052930         0       0
# 3197     49     61  51.48  31.34375  60.271229  5.944216         0       0
# 3198     49     62  51.48  32.40625  60.830547  5.835773         0       0
# 3199     49     63  51.48  33.46875  61.403156  5.727782         0       0
#
#                 xg
# 0     1.753951e-19
# 1     6.445589e-19
# 2     2.369935e-18
# 3     8.719120e-18
# 4     3.210045e-17
# ...            ...
# 3195  4.855749e-26
# 3196  2.512004e-26
# 3197  1.277836e-26
# 3198  6.395143e-27
# 3199  3.150431e-27
#
# [3200 rows x 9 columns]

# %%
xg_heatmap = np.zeros((m, n))

for i in shot_grid.index:
    x_idx = shot_grid.at[i, 'x_idx']
    y_idx = shot_grid.at[i, 'y_idx']
    xg_heatmap[x_idx, y_idx] = shot_grid.at[i, 'xg']

fig, ax = draw_pitch(pitch='white', line='black', orientation='v', view='h')
img = ax.imshow(xg_heatmap, extent=[0, 68, 52, 104], vmin=0, vmax=0.3, cmap='jet', alpha=0.7)
fig.colorbar(img, ax=ax)
plt.title('Goal probability (xG)', fontdict={'size': 25})

plt.show()

# %% [markdown]
# ## xG 집계 및 분석

# %% [markdown]
# ##### (1) 리그 별 xG 학습

# %%
competitions = [x for x in os.listdir(os.path.join(DATA_DIR, 'refined_events'))]
test_competitions = ['England', 'World_Cup']
train_competitions = [x for x in competitions if x not in test_competitions]
train_competitions, test_competitions
# Out:
# (['Germany', 'France', 'European_Championship', 'Italy', 'Spain'],
#  ['England', 'World_Cup'])

# %%
def get_events(competition_names):
  match_events_list = []
  for competition_name in competition_names:
      matches_path = os.path.join(DATA_DIR, "matches", f"matches_{competition_name}.json")
      with open(matches_path) as json_data:
          matches = json.load(json_data)
      match_df = pd.DataFrame(matches)

      for match_id in tqdm(match_df.wyId, desc=f"{competition_name} precessing...."):
          match_events = pd.read_pickle(os.path.join(DATA_DIR, 'refined_events', competition_name, f'{match_id}.pkl'))
          match_events['competition_name'] = competition_name
          match_events_list.append(match_events)

  return pd.concat(match_events_list, ignore_index=True)

# %%
train_events = get_events(train_competitions)
train_events.head()
# Out:
# Germany precessing....:   0%|          | 0/306 [00:00<?, ?it/s]
# France precessing....:   0%|          | 0/380 [00:00<?, ?it/s]
# European_Championship precessing....:   0%|          | 0/51 [00:00<?, ?it/s]
# Italy precessing....:   0%|          | 0/380 [00:00<?, ?it/s]
# Spain precessing....:   0%|          | 0/380 [00:00<?, ?it/s]
#   match_id   event_id period    time team_id       team_name player_id  \
# 0  2517036  251207291     1H   6.079    2444  Bayern München    209091
# 1  2517036  251207292     1H   8.106    2444  Bayern München     70096
# 2  2517036  251207293     1H  10.012    2444  Bayern München      3345
# 3  2517036  251207294     1H  11.942    2444  Bayern München     14795
# 4  2517036  251207295     1H  13.466    2444  Bayern München     70096
#
#         player_name          event_type sub_event_type        tags  start_x  \
# 0        C. Tolisso                Pass    Simple pass  [Accurate]    52.00
# 1      J. Rodríguez                Pass    Simple pass  [Accurate]    41.60
# 2  Thiago Alcântara                Pass    Simple pass  [Accurate]    34.32
# 3        M. Hummels                Pass    Simple pass  [Accurate]    24.96
# 4      J. Rodríguez  Others on the ball          Touch          []    35.36
#
#    start_y  end_x  end_y competition_name
# 0    33.32  41.60  42.16          Germany
# 1    42.16  34.32  30.60          Germany
# 2    30.60  24.96  41.48          Germany
# 3    41.48  35.36  51.68          Germany
# 4    51.68  45.76  42.84          Germany

# %%
test_events = get_events(test_competitions)
test_events.head()
# Out:
# England precessing....:   0%|          | 0/380 [00:00<?, ?it/s]
# World_Cup precessing....:   0%|          | 0/64 [00:00<?, ?it/s]
#   match_id   event_id period    time team_id        team_name player_id  \
# 0  2500089  251700146     1H   2.764    1659  AFC Bournemouth      9637
# 1  2500089  251700147     1H   4.761    1659  AFC Bournemouth      8351
# 2  2500089  251700148     1H   5.533    1659  AFC Bournemouth      9285
# 3  2500089  251700161     1H   7.708    1659  AFC Bournemouth    239411
# 4  2500089  251700149     1H  11.615    1659  AFC Bournemouth      9637
#
#   player_name event_type sub_event_type        tags  start_x  start_y  end_x  \
# 0     J. King       Pass    Simple pass  [Accurate]    52.00    34.00  41.60
# 1   A. Surman       Pass    Simple pass  [Accurate]    41.60    37.40  40.56
# 2  C. Daniels       Pass    Simple pass  [Accurate]    40.56    57.80  32.24
# 3    T. Mings       Pass      High pass  [Accurate]    32.24    47.60  68.64
# 4     J. King       Pass    Simple pass  [Accurate]    68.64    48.96  73.84
#
#    end_y competition_name
# 0  37.40          England
# 1  57.80          England
# 2  47.60          England
# 3  48.96          England
# 4  55.76          England

# %%
train_shots = train_events[
    (train_events['event_type'] == 'Shot') | (train_events['sub_event_type'].isin(['Free kick shot', 'Penalty']))
].reset_index(drop=True)

train_shots.head()
# Out:
#   match_id   event_id period     time team_id       team_name player_id  \
# 0  2517036  251207326     1H   75.347    2444  Bayern München     70096
# 1  2517036  251207376     1H  184.082    2444  Bayern München     14817
# 2  2517036  251207486     1H  296.845    2445       Stuttgart     14845
# 3  2517036  251207570     1H   494.65    2445       Stuttgart    349099
# 4  2517036  251207760     1H  1230.73    2444  Bayern München    209091
#
#       player_name event_type sub_event_type  \
# 0    J. Rodríguez       Shot           Shot
# 1  R. Lewandowski       Shot           Shot
# 2      D. Ginczek       Shot           Shot
# 3      O. Mangala       Shot           Shot
# 4      C. Tolisso       Shot           Shot
#
#                                                 tags  start_x  start_y  \
# 0                 [Left foot, Blocked, Not accurate]    78.00    34.68
# 1  [Left foot, Position: Out low right, Not accur...    84.24    29.92
# 2  [Goal, Right foot, Opportunity, Position: Goal...    99.84    36.04
# 3  [Right foot, Opportunity, Position: Goal cente...    79.04    26.52
# 4  [Goal, Right foot, Opportunity, Position: Goal...    92.56    27.88
#
#     end_x  end_y competition_name
# 0   92.56  29.92          Germany
# 1  104.00  34.00          Germany
# 2  104.00  34.00          Germany
# 3  104.00  34.00          Germany
# 4  104.00  34.00          Germany

# %%
test_shots = test_events[
    (test_events['event_type'] == 'Shot') | (test_events['sub_event_type'].isin(['Free kick shot', 'Penalty']))
].reset_index(drop=True)

test_shots.head()
# Out:
#   match_id   event_id period      time team_id        team_name player_id  \
# 0  2500089  251700604     1H  1239.334    1659  AFC Bournemouth    245813
# 1  2500089  251700478     1H  1324.246    1646          Burnley      8980
# 2  2500089  251700689     1H  1494.384    1659  AFC Bournemouth      9285
# 3  2500089  251700693     1H  1523.716    1659  AFC Bournemouth      8351
# 4  2500089  251700755     1H  1651.209    1659  AFC Bournemouth      9637
#
#    player_name event_type sub_event_type  \
# 0   L. Mousset       Shot           Shot
# 1  J. Hendrick       Shot           Shot
# 2   C. Daniels       Shot           Shot
# 3    A. Surman       Shot           Shot
# 4      J. King       Shot           Shot
#
#                                                 tags  start_x  start_y  \
# 0  [Right foot, Opportunity, Position: Goal low c...    91.52    26.52
# 1  [Right foot, Opportunity, Position: Goal cente...    81.12    42.16
# 2  [Left foot, Opportunity, Position: Goal center...    90.48    48.28
# 3                 [Left foot, Blocked, Not accurate]    80.08    34.00
# 4  [Right foot, Opportunity, Position: Out high c...    92.56    11.56
#
#     end_x  end_y competition_name
# 0  104.00  34.00          England
# 1  104.00  34.00          England
# 2  104.00  34.00          England
# 3   90.48  33.32          England
# 4  104.00  34.00          England

# %%
#x,y좌표는 왼쪽 아래가 (0,0)으로 설정되어있음
#상대팀골대중앙을 기준으로 (x,y)를 설정해야하므로
#(104-start_x , start_y-34)로 설정함
def get_shot_features(shots):
  shot_features = pd.DataFrame(index=shots.index)
  shot_features['x'] = 104 - shots['start_x']
  shot_features['y'] = shots['start_y'] - 34
  shot_features

  #피타고라스 거리 = norm2을 적용함
  shot_features['distance'] = shot_features[['x', 'y']].apply(np.linalg.norm, axis=1)

  x = shot_features['x']
  y = shot_features['y']
  goal_width = 7.32
  angles = np.arctan((goal_width * x) / (x ** 2 + y ** 2 - (goal_width / 2) ** 2)) * 180 / np.pi
  shot_features['angle'] = np.where(angles >= 0, angles, angles + 180)
  shot_features

  shot_features['freekick'] = (shots['event_type'] == 'Free kick').astype(int)
  shot_features['header'] = shots['tags'].apply(lambda x: 'Head/body' in x).astype(int)
  shot_features['goal'] = shots['tags'].apply(lambda x: 'Goal' in x).astype(int)

  return shot_features

# %%
train_shot_features = get_shot_features(train_shots)
train_shot_features
# Out:
#            x      y   distance      angle  freekick  header  goal
# 0      26.00   0.68  26.008891  16.015062         0       0     0
# 1      19.76  -4.08  20.176818  20.172657         0       0     0
# 2       4.16   2.04   4.633271  75.154201         0       0     1
# 3      24.96  -7.48  26.056707  15.350572         0       0     0
# 4      11.44  -6.12  12.974128  28.391175         0       0     1
# ...      ...    ...        ...        ...       ...     ...   ...
# 35486  10.40  12.24  16.061681  17.289149         0       1     0
# 35487  21.84  10.20  24.104473  15.729482         0       0     0
# 35488  31.20  -1.36  31.229627  13.356507         0       0     0
# 35489  11.44 -11.56  16.263677  18.442533         0       0     0
# 35490  11.44  -2.72  11.758912  33.845389         0       1     0
#
# [35491 rows x 7 columns]

# %%
test_shot_features = get_shot_features(test_shots)
test_shot_features
# Out:
#            x      y   distance      angle  freekick  header  goal
# 0      12.48  -7.48  14.549942  24.734188         0       0     0
# 1      22.88   8.16  24.291562  16.194438         0       0     0
# 2      13.52  14.28  19.664913  14.847734         0       0     0
# 3      23.92   0.00  23.920000  17.398716         0       0     0
# 4      11.44 -22.44  25.187838   7.679526         0       0     0
# ...      ...    ...        ...        ...       ...     ...   ...
# 10449  10.40  -6.12  12.067079  29.932171         0       1     0
# 10450  13.52 -12.92  18.700717  16.397129         0       0     0
# 10451  31.20   6.80  31.932429  12.787102         0       0     0
# 10452  14.56  14.28  20.393921  14.830569         0       0     1
# 10453  19.76 -11.56  22.893038  15.813597         1       0     1
#
# [10454 rows x 7 columns]

# %%
features = ['x', 'y', 'distance', 'angle', 'freekick', 'header']
X_train = train_shot_features[features]
y_train = train_shot_features['goal']

X_test = test_shot_features[features]
y_test = test_shot_features['goal']

# 데이터 스케일링 (거리 기반 모델 등을 위해)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 실험할 모델
model = LogisticRegression(max_iter=1000)

# 각 모델별 학습 및 평가
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
y_pred_proba = model.predict_proba(X_test_scaled)[:, 1]

accuracy = accuracy_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

# 6. 결과 출력
print(f"--- Model: {model}, Features: {features} ---")
print(f"  Accuracy = {accuracy:.4f}")
print(f"  ROC AUC = {roc_auc:.4f}")
print("-" * 30)

preds = pd.concat([pd.DataFrame(X_test, columns=features).reset_index(drop=True),
                  pd.DataFrame(y_test, columns=["goal"]).reset_index(drop=True),
                  pd.DataFrame(y_pred_proba, columns=["xg"]).reset_index(drop=True)],
                  axis=1, ignore_index=False)
preds
# Out:
# --- Model: LogisticRegression(max_iter=1000), Features: ['x', 'y', 'distance', 'angle', 'freekick', 'header'] ---
#   Accuracy = 0.8966
#   ROC AUC = 0.7807
# ------------------------------
#            x      y   distance      angle  freekick  header  goal        xg
# 0      12.48  -7.48  14.549942  24.734188         0       0     0  0.123189
# 1      22.88   8.16  24.291562  16.194438         0       0     0  0.035623
# 2      13.52  14.28  19.664913  14.847734         0       0     0  0.053336
# 3      23.92   0.00  23.920000  17.398716         0       0     0  0.038679
# 4      11.44 -22.44  25.187838   7.679526         0       0     0  0.015292
# ...      ...    ...        ...        ...       ...     ...   ...       ...
# 10449  10.40  -6.12  12.067079  29.932171         0       1     0  0.069434
# 10450  13.52 -12.92  18.700717  16.397129         0       0     0  0.056807
# 10451  31.20   6.80  31.932429  12.787102         0       0     0  0.013031
# 10452  14.56  14.28  20.393921  14.830569         0       0     1  0.049337
# 10453  19.76 -11.56  22.893038  15.813597         1       0     1  0.155623
#
# [10454 rows x 8 columns]

# %%
df_shots = pd.concat([test_shots, preds], axis=1)
df_shots
# Out:
#       match_id   event_id period      time team_id        team_name player_id  \
# 0      2500089  251700604     1H  1239.334    1659  AFC Bournemouth    245813
# 1      2500089  251700478     1H  1324.246    1646          Burnley      8980
# 2      2500089  251700689     1H  1494.384    1659  AFC Bournemouth      9285
# 3      2500089  251700693     1H  1523.716    1659  AFC Bournemouth      8351
# 4      2500089  251700755     1H  1651.209    1659  AFC Bournemouth      9637
# ...        ...        ...    ...       ...     ...              ...       ...
# 10449  2057954  258613574     2H  1890.677   14358           Russia    103682
# 10450  2057954  258613974     2H  2193.564   16521     Saudi Arabia    122615
# 10451  2057954  258613669     2H  2317.852   14358           Russia    220971
# 10452  2057954  258613749     2H  2748.726   14358           Russia      4513
# 10453  2057954  258613773     2H  2939.438   14358           Russia    257800
#
#          player_name event_type  sub_event_type  ...  end_y  competition_name  \
# 0         L. Mousset       Shot            Shot  ...  34.00           England
# 1        J. Hendrick       Shot            Shot  ...  34.00           England
# 2         C. Daniels       Shot            Shot  ...  34.00           England
# 3          A. Surman       Shot            Shot  ...  33.32           England
# 4            J. King       Shot            Shot  ...  34.00           England
# ...              ...        ...             ...  ...    ...               ...
# 10449      R. Zobnin       Shot            Shot  ...  34.00         World_Cup
# 10450  Hattan Bahbir       Shot            Shot  ...  25.84         World_Cup
# 10451     D. Kuzyaev       Shot            Shot  ...  34.00         World_Cup
# 10452   D. Cheryshev       Shot            Shot  ...  34.00         World_Cup
# 10453     A. Golovin  Free kick  Free kick shot  ...  34.00         World_Cup
#
#            x      y   distance      angle  freekick  header  goal        xg
# 0      12.48  -7.48  14.549942  24.734188         0       0     0  0.123189
# 1      22.88   8.16  24.291562  16.194438         0       0     0  0.035623
# 2      13.52  14.28  19.664913  14.847734         0       0     0  0.053336
# 3      23.92   0.00  23.920000  17.398716         0       0     0  0.038679
# 4      11.44 -22.44  25.187838   7.679526         0       0     0  0.015292
# ...      ...    ...        ...        ...       ...     ...   ...       ...
# 10449  10.40  -6.12  12.067079  29.932171         0       1     0  0.069434
# 10450  13.52 -12.92  18.700717  16.397129         0       0     0  0.056807
# 10451  31.20   6.80  31.932429  12.787102         0       0     0  0.013031
# 10452  14.56  14.28  20.393921  14.830569         0       0     1  0.049337
# 10453  19.76 -11.56  22.893038  15.813597         1       0     1  0.155623
#
# [10454 rows x 24 columns]

# %%
match_id = 2057987

matches_path = os.path.join(DATA_DIR, "matches", f"matches_World_Cup.json")
with open(matches_path) as json_data:
    matches = json.load(json_data)
match_df = pd.DataFrame(matches)

match_df["team_names"] = match_df.label.apply(lambda l: l.split(', ')[0])
match_df["team1_name"] = match_df.team_names.apply(
    lambda t: t.encode('ascii', 'strict').decode('unicode-escape').split(' - ')[0]
)
match_df["team2_name"] = match_df.team_names.apply(
    lambda t: t.encode('ascii', 'strict').decode('unicode-escape').split(' - ')[1]
)

match_df
# Out:
#     status  roundId  gameweek  \
# 0   Played  4165368         0
# 1   Played  4165367         0
# 2   Played  4165366         0
# 3   Played  4165366         0
# 4   Played  4165365         0
# ..     ...      ...       ...
# 59  Played  4165363         1
# 60  Played  4165363         1
# 61  Played  4165363         1
# 62  Played  4165363         1
# 63  Played  4165363         1
#
#                                             teamsData  seasonId  \
# 0   {'9598': {'scoreET': 0, 'coachId': 122788, 'si...     10078
# 1   {'2413': {'scoreET': 0, 'coachId': 276858, 'si...     10078
# 2   {'2413': {'scoreET': 1, 'coachId': 276858, 'si...     10078
# 3   {'5629': {'scoreET': 0, 'coachId': 8605, 'side...     10078
# 4   {'14358': {'scoreET': 2, 'coachId': 264893, 's...     10078
# ..                                                ...       ...
# 59  {'8493': {'scoreET': 0, 'coachId': 134090, 'si...     10078
# 60  {'9905': {'scoreET': 0, 'coachId': 137521, 'si...     10078
# 61  {'10840': {'scoreET': 0, 'coachId': 136612, 's...     10078
# 62  {'16129': {'scoreET': 0, 'coachId': 33204, 'si...     10078
# 63  {'14358': {'scoreET': 0, 'coachId': 264893, 's...     10078
#
#                 dateutc  winner                         venue     wyId  \
# 0   2018-07-15 15:00:00    4418  Olimpiyskiy stadion Luzhniki  2058017
# 1   2018-07-14 14:00:00    5629           Stadion Krestovskyi  2058016
# 2   2018-07-11 18:00:00    9598  Olimpiyskiy stadion Luzhniki  2058015
# 3   2018-07-10 18:00:00    4418           Stadion Krestovskyi  2058014
# 4   2018-07-07 18:00:00    9598     Olimpiyskiy Stadion Fisht  2058012
# ..                  ...     ...                           ...      ...
# 59  2018-06-16 10:00:00    4418                  Kazan' Arena  2057966
# 60  2018-06-15 18:00:00       0     Olimpiyskiy Stadion Fisht  2057960
# 61  2018-06-15 15:00:00   10840           Stadion Krestovskyi  2057961
# 62  2018-06-15 12:00:00   15670           Stadion Central'nyj  2057955
# 63  2018-06-14 15:00:00   14358  Olimpiyskiy stadion Luzhniki  2057954
#
#                            label                                date  \
# 0        France - Croatia, 4 - 2   July 15, 2018 at 5:00:00 PM GMT+2
# 1       Belgium - England, 2 - 0   July 14, 2018 at 4:00:00 PM GMT+2
# 2   Croatia - England, 2 - 1 (E)   July 11, 2018 at 8:00:00 PM GMT+2
# 3        France - Belgium, 1 - 0   July 10, 2018 at 8:00:00 PM GMT+2
# 4    Russia - Croatia, 2 - 2 (P)    July 7, 2018 at 8:00:00 PM GMT+2
# ..                           ...                                 ...
# 59     France - Australia, 2 - 1  June 16, 2018 at 12:00:00 PM GMT+2
# 60       Portugal - Spain, 3 - 3   June 15, 2018 at 8:00:00 PM GMT+2
# 61         Morocco - Iran, 0 - 1   June 15, 2018 at 5:00:00 PM GMT+2
# 62        Egypt - Uruguay, 0 - 1   June 15, 2018 at 2:00:00 PM GMT+2
# 63  Russia - Saudi Arabia, 5 - 0   June 14, 2018 at 5:00:00 PM GMT+2
#
#    groupName                                           referees   duration  \
# 0             [{'refereeId': 378051, 'role': 'referee'}, {'r...    Regular
# 1             [{'refereeId': 380599, 'role': 'referee'}, {'r...    Regular
# 2             [{'refereeId': 384995, 'role': 'referee'}, {'r...  ExtraTime
# 3             [{'refereeId': 378232, 'role': 'referee'}, {'r...    Regular
# 4             [{'refereeId': 378204, 'role': 'referee'}, {'r...  Penalties
# ..       ...                                                ...        ...
# 59   Group C  [{'refereeId': 378232, 'role': 'referee'}, {'r...    Regular
# 60   Group B  [{'refereeId': 377206, 'role': 'referee'}, {'r...    Regular
# 61   Group B  [{'refereeId': 384995, 'role': 'referee'}, {'r...    Regular
# 62   Group A  [{'refereeId': 377215, 'role': 'referee'}, {'r...    Regular
# 63   Group A  [{'refereeId': 378051, 'role': 'referee'}, {'r...    Regular
#
#     competitionId             team_names team1_name    team2_name
# 0              28       France - Croatia     France       Croatia
# 1              28      Belgium - England    Belgium       England
# 2              28      Croatia - England    Croatia       England
# 3              28       France - Belgium     France       Belgium
# 4              28       Russia - Croatia     Russia       Croatia
# ..            ...                    ...        ...           ...
# 59             28     France - Australia     France     Australia
# 60             28       Portugal - Spain   Portugal         Spain
# 61             28         Morocco - Iran    Morocco          Iran
# 62             28        Egypt - Uruguay      Egypt       Uruguay
# 63             28  Russia - Saudi Arabia     Russia  Saudi Arabia
#
# [64 rows x 18 columns]

# %%
team1_name, team2_name = match_df[match_df['wyId'] == match_id][['team1_name', 'team2_name']].values[0]

match_shots = df_shots[df_shots['match_id'] == match_id].reset_index(drop=True)
match_shots['display_name'] = match_shots.apply(
    lambda x: f"{x['player_name']}, " +
    f"{x['period']} {int(x['time'] // 60):02d}:{int(x['time'] % 60):02d}, " +
    f"xG: {round(x['xg'], 3)}", axis=1
)

#기존 start_x, start_y좌표로 변환 => 팀마다 다르게 설정해야해서
team2_x = match_shots.loc[match_shots['team_name'] == team2_name, 'x']
team1_y = match_shots.loc[match_shots['team_name'] == team1_name, 'y']
team2_y = match_shots.loc[match_shots['team_name'] == team2_name, 'y']
match_shots.loc[match_shots['team_name'] == team2_name, 'x'] = 104 - team2_x
match_shots.loc[match_shots['team_name'] == team1_name, 'y'] = 34 - team1_y
match_shots.loc[match_shots['team_name'] == team2_name, 'y'] = 34 + team2_y

match_shots.head()
# Out:
#   match_id   event_id period      time team_id       team_name player_id  \
# 0  2057987  259956999     1H   698.173   15473          Mexico      7941
# 1  2057987  259957180     1H  1275.442   14855  Korea Republic     14911
# 2  2057987  259957182     1H  1277.147   14855  Korea Republic     14911
# 3  2057987  259965138     1H  1281.101   14855  Korea Republic     14911
# 4  2057987  259957220     1H  1339.263   14855  Korea Republic     61962
#
#      player_name event_type sub_event_type  ... competition_name      x  \
# 0   J. Hernández       Shot           Shot  ...        World_Cup  91.52
# 1  Son Heung-Min       Shot           Shot  ...        World_Cup  13.52
# 2  Son Heung-Min       Shot           Shot  ...        World_Cup  12.48
# 3  Son Heung-Min       Shot           Shot  ...        World_Cup  21.84
# 4  Sung-Yeung Ki       Shot           Shot  ...        World_Cup  11.44
#
#        y   distance      angle freekick  header  goal        xg  \
# 0  27.88  13.899813  26.933236        0       1     0  0.052758
# 1  45.56  17.788311  18.086581        0       0     0  0.067976
# 2  45.56  17.011290  18.314813        0       0     0  0.074227
# 3  41.48  23.085407  17.103758        0       0     0  0.039530
# 4  37.40  11.934555  32.982052        0       1     0  0.078959
#
#                          display_name
# 0   J. Hernández, 1H 11:38, xG: 0.053
# 1  Son Heung-Min, 1H 21:15, xG: 0.068
# 2  Son Heung-Min, 1H 21:17, xG: 0.074
# 3   Son Heung-Min, 1H 21:21, xG: 0.04
# 4  Sung-Yeung Ki, 1H 22:19, xG: 0.079
#
# [5 rows x 25 columns]

# %% [markdown]
# ##### (2) 슈팅 위치 및 xG 시각화

# %%
match_shots_success = match_shots[match_shots['tags'].apply(lambda x: 'Goal' in x)]
match_shots_failed = match_shots[match_shots['tags'].apply(lambda x: 'Goal' not in x)]

team1_goals = match_shots_success[match_shots_success['team_name'] == team1_name]
team2_goals = match_shots_success[match_shots_success['team_name'] == team2_name]

team1_not_goals = match_shots_failed[match_shots_failed['team_name'] == team1_name]
team2_not_goals = match_shots_failed[match_shots_failed['team_name'] == team2_name]


team1_goal_trace = go.Scatter(
    x=team1_goals['start_x'],
    y=team1_goals['start_y'],
    name=f"{team1_name}: success shot",
    text=team1_goals['display_name'],
    mode='markers',
    marker=dict(
        color='red', size=np.sqrt(team1_goals['xg']) * 50,
        symbol=team1_goals['freekick'].apply(lambda x: 'square' if x == 1 else 'circle')
    )
)

team2_goal_trace = go.Scatter(
    x=team2_goals['start_x'],
    y=team2_goals['start_y'],
    name=f"{team2_name}: success shot",
    text=team2_goals['display_name'],
    mode='markers',
    marker=dict(
        color='blue', size=np.sqrt(team2_goals['xg']) * 50,
        symbol=team2_goals['freekick'].apply(lambda x: 'square' if x == 1 else 'circle')
    )
)

team1_not_goal_trace = go.Scatter(
    x=team1_not_goals['start_x'],
    y=team1_not_goals['start_y'],
    name=f"{team1_name}: failed shot",
    text=match_shots_failed['display_name'],
    mode='markers',
    marker=dict(
        color='green', size=np.sqrt(match_shots_failed['xg']) * 50,
        symbol=match_shots_failed['freekick'].apply(lambda x: 'square' if x == 1 else 'circle')
    )
)

team2_not_goal_trace = go.Scatter(
    x=team2_not_goals['start_x'],
    y=team2_not_goals['start_y'],
    name=f"{team2_name}: failed shot",
    text=match_shots_failed['display_name'],
    mode='markers',
    marker=dict(
        color='purple', size=np.sqrt(match_shots_failed['xg']) * 50,
        symbol=match_shots_failed['freekick'].apply(lambda x: 'square' if x == 1 else 'circle')
    )
)

team1_shots = match_shots[match_shots['team_name'] == team1_name]
team2_shots = match_shots[match_shots['team_name'] == team2_name]
team1_xg = team1_shots['xg'].suㅇm().round(2)
team2_xg = team2_shots['xg'].sum().round(2)

title = f"{team1_name} - {team2_name} (xG: {team1_xg} - {team2_xg})"
fig = go.Figure(data=[team1_not_goal_trace, team2_not_goal_trace, team1_goal_trace, team2_goal_trace], layout=get_pitch_layout(title))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f19463c0-e164-4ecc-9ae9-331956151041" class="plotly-graph-div" style="height:600px; width:825px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f19463c0-e164-4ecc-9ae9-331956151041")) {                    Plotly.newPlot(                        "f19463c0-e164-4ecc-9ae9-331956151041",                        [{"marker":{"color":"green","size":[11.484526141493994,13.036134859649875,13.622338478971036,9.941118026787523,14.04986099510667,16.996279696547486,15.712628675696338,13.8283279567819,11.966652011561145,8.226922316970523,11.37612173328216,6.819127659660186,8.978914831992347,16.227753755641604,4.990120949839335,6.174167137018222,10.396003609953086,14.542882878807692,11.053209215686524,20.24190745975783,7.1815234945907385,12.208142078276007,5.922802829633804,6.779131758181601,8.525691951632728,10.12424458732626],"symbol":["circle","circle","circle","circle","circle","circle","square","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle"]},"mode":"markers","name":"Korea Republic: failed shot","text":["J. Hernández, 1H 11:38, xG: 0.053","Son Heung-Min, 1H 21:15, xG: 0.068","Son Heung-Min, 1H 21:17, xG: 0.074","Son Heung-Min, 1H 21:21, xG: 0.04","Sung-Yeung Ki, 1H 22:19, xG: 0.079","M. Layún, 1H 27:11, xG: 0.116","Son Heung-Min, 1H 30:52, xG: 0.099","Son Heung-Min, 1H 38:36, xG: 0.076","H. Lozano, 1H 42:34, xG: 0.057","Seon-Min Moon, 1H 44:21, xG: 0.027","Son Heung-Min, 1H 44:24, xG: 0.052","H. Lozano, 2H 05:02, xG: 0.019","J. Hernández, 2H 06:05, xG: 0.032","Seon-Min Moon, 2H 06:50, xG: 0.105","Jae-Sung Lee, 2H 07:42, xG: 0.01","Sung-Yeung Ki, 2H 10:44, xG: 0.015","A. Guardado, 2H 12:42, xG: 0.043","A. Guardado, 2H 12:46, xG: 0.085","H. Lozano, 2H 14:52, xG: 0.049","Jae-Sung Lee, 2H 16:01, xG: 0.164","C. Vela, 2H 16:30, xG: 0.021","Hwang Hee-Chan, 2H 24:09, xG: 0.06","Sung-Yeung Ki, 2H 28:05, xG: 0.014","Jae-Sung Lee, 2H 36:43, xG: 0.018","Son Heung-Min, 2H 42:46, xG: 0.029","H. Herrera, 2H 46:38, xG: 0.041"],"x":[90.48,91.52000000000001,82.16,92.56,75.92,100.88000000000001,81.12,83.2,91.52000000000001,89.44,86.32000000000001,90.48,83.2,73.84,75.92,78.0],"y":[22.44,22.44,26.520000000000003,30.6,34.0,47.6,23.12,40.120000000000005,25.16,9.520000000000001,55.760000000000005,36.04,34.68,27.200000000000003,27.200000000000003,35.36],"type":"scatter"},{"marker":{"color":"purple","size":[11.484526141493994,13.036134859649875,13.622338478971036,9.941118026787523,14.04986099510667,16.996279696547486,15.712628675696338,13.8283279567819,11.966652011561145,8.226922316970523,11.37612173328216,6.819127659660186,8.978914831992347,16.227753755641604,4.990120949839335,6.174167137018222,10.396003609953086,14.542882878807692,11.053209215686524,20.24190745975783,7.1815234945907385,12.208142078276007,5.922802829633804,6.779131758181601,8.525691951632728,10.12424458732626],"symbol":["circle","circle","circle","circle","circle","circle","square","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle"]},"mode":"markers","name":"Mexico: failed shot","text":["J. Hernández, 1H 11:38, xG: 0.053","Son Heung-Min, 1H 21:15, xG: 0.068","Son Heung-Min, 1H 21:17, xG: 0.074","Son Heung-Min, 1H 21:21, xG: 0.04","Sung-Yeung Ki, 1H 22:19, xG: 0.079","M. Layún, 1H 27:11, xG: 0.116","Son Heung-Min, 1H 30:52, xG: 0.099","Son Heung-Min, 1H 38:36, xG: 0.076","H. Lozano, 1H 42:34, xG: 0.057","Seon-Min Moon, 1H 44:21, xG: 0.027","Son Heung-Min, 1H 44:24, xG: 0.052","H. Lozano, 2H 05:02, xG: 0.019","J. Hernández, 2H 06:05, xG: 0.032","Seon-Min Moon, 2H 06:50, xG: 0.105","Jae-Sung Lee, 2H 07:42, x ...

# %% [markdown]
# ##### (3) 선수별 시즌 전체 xG 및 부가 지표 집계

# %%
# 선수별 슈팅/유효슈팅/득점 횟수 집계
shots = df_shots[df_shots['competition_name'] == 'England'].reset_index(drop=True)
shots_on_target = df_shots[df_shots['tags'].apply(lambda x: 'Accurate' in x)].reset_index(drop=True)
goals = df_shots[df_shots['tags'].apply(lambda x: 'Goal' in x)].reset_index(drop=True)

player_shot_counts = shots.groupby(['team_id', 'team_name', 'player_id', 'player_name'])['event_id'].count()
player_sot_counts = shots_on_target.groupby(['team_id', 'team_name', 'player_id', 'player_name'])['event_id'].count()
player_goal_counts = goals.groupby(['team_id', 'team_name', 'player_id', 'player_name'])['event_id'].count()

player_stats = pd.concat([player_shot_counts, player_sot_counts, player_goal_counts], axis=1).fillna(0).astype(int)
player_stats.columns = ['Shots', 'SoT', 'Goals']
player_stats
# Out:
#                                             Shots  SoT  Goals
# team_id team_name player_id player_name
# 1609    Arsenal   3319      M. Özil            39   14      4
#                   3361      A. Sánchez         69   28      7
#                   3560      Nacho Monreal      21    8      5
#                   7855      L. Koscielny        8    2      2
#                   7856      P. Mertesacker      2    2      1
# ...                                           ...  ...    ...
# 19314   Senegal   28529     Y. Sabaly           0    1      0
#                   97582     M. Konaté           0    1      0
#                   256480    B. Keita            0    1      0
#                   375348    M. Wagué            0    1      1
#                   448079    I. Sarr             0    2      0
#
# [692 rows x 3 columns]

# %%
player_stats.sort_values('Goals', ascending=False)[:20].reset_index()
# Out:
#     team_id               team_name  player_id      player_name  Shots  SoT  \
# 0      1612               Liverpool     120353    Mohamed Salah    142   68
# 1      1624       Tottenham Hotspur       8717          H. Kane    175   74
# 2      1625         Manchester City       8325        S. Agüero     91   42
# 3      1631          Leicester City      12829         J. Vardy     66   34
# 4      1625         Manchester City      11066      R. Sterling     80   35
# 5      1611       Manchester United       7905        R. Lukaku     80   41
# 6      1612               Liverpool      15808  Roberto Firmino     80   37
# 7      1609                 Arsenal      25413     A. Lacazette     65   36
# 8      1625         Manchester City     340386    Gabriel Jesus     55   31
# 9      1610                 Chelsea      25707        E. Hazard     65   34
# 10     1651  Brighton & Hove Albion       8416        G. Murray     50   24
# 11     1624       Tottenham Hotspur      14911    Son Heung-Min     70   31
# 12     1631          Leicester City      26150        R. Mahrez     71   36
# 13     1610                 Chelsea       3324    Álvaro Morata     74   33
# 14     1624       Tottenham Hotspur         54       C. Eriksen     97   40
# 15     1633         West Ham United      14703    M. Arnautović     67   31
# 16     1625         Manchester City     245364          L. Sané     54   21
# 17     1628          Crystal Palace     127537   L. Milivojević     42   16
# 18     1612               Liverpool      25747          S. Mané     67   26
# 19     1609                 Arsenal      25867    P. Aubameyang     29   18
#
#     Goals
# 0      32
# 1      29
# 2      21
# 3      20
# 4      18
# 5      16
# 6      15
# 7      14
# 8      13
# 9      12
# 10     12
# 11     12
# 12     12
# 13     11
# 14     11
# 15     11
# 16     10
# 17     10
# 18     10
# 19     10

# %%
# 선수별 xG 집계 및 정렬
player_stats['xG'] = shots.groupby(['team_id', 'team_name', 'player_id', 'player_name'])['xg'].sum()
player_stats.sort_values('xG', ascending=False)[:20].reset_index()
# Out:
#     team_id               team_name  player_id      player_name  Shots  SoT  \
# 0      1624       Tottenham Hotspur       8717          H. Kane    175   74
# 1      1612               Liverpool     120353    Mohamed Salah    142   68
# 2      1625         Manchester City      11066      R. Sterling     80   35
# 3      1625         Manchester City       8325        S. Agüero     91   42
# 4      1611       Manchester United       7905        R. Lukaku     80   41
# 5      1631          Leicester City      12829         J. Vardy     66   34
# 6      1625         Manchester City     340386    Gabriel Jesus     55   31
# 7      1609                 Arsenal      25413     A. Lacazette     65   36
# 8      1651  Brighton & Hove Albion       8416        G. Murray     50   24
# 9      1633         West Ham United      14703    M. Arnautović     67   31
# 10     1610                 Chelsea       3324    Álvaro Morata     74   33
# 11     1644                 Watford     377071      Richarlison     92   23
# 12     1628          Crystal Palace      38031       C. Benteke     55   20
# 13     1612               Liverpool      25747          S. Mané     67   26
# 14     1613        Newcastle United      12536         D. Gayle     53   20
# 15     1624       Tottenham Hotspur      13484          D. Alli     70   18
# 16     1624       Tottenham Hotspur         54       C. Eriksen     97   40
# 17     1612               Liverpool      15808  Roberto Firmino     80   37
# 18     1628          Crystal Palace       8422          W. Zaha     67   28
# 19     1627    West Bromwich Albion       8958     J. Rodriguez     67   25
#
#     Goals         xG
# 0      29  25.735036
# 1      32  19.111135
# 2      18  15.422046
# 3      21  15.345645
# 4      16  15.169959
# 5      20  13.382514
# 6      13  12.017613
# 7      14  11.705828
# 8      12  11.163122
# 9      11  10.786956
# 10     11  10.598518
# 11      5  10.537728
# 12      3  10.189445
# 13     10   9.339263
# 14      6   8.996998
# 15      9   8.943468
# 16     11   8.497102
# 17     15   8.471428
# 18      9   8.373648
# 19      7   8.328297

# %% [markdown]
# ##### (3) 선수별 득점-xG 차이(dG) 집계 및 정렬
# - 골결정력을 판단 (주어진 xg대비 얼마나 득점을 이뤘는지)
# $$ dG = 득점-xg $$

# %%
player_stats['dG'] = player_stats['Goals'] - player_stats['xG']
player_stats.sort_values('dG', ascending=False)[:20].reset_index()
# Out:
#     team_id               team_name  player_id        player_name  Shots  SoT  \
# 0      1612               Liverpool     120353      Mohamed Salah    142   68
# 1      1631          Leicester City      12829           J. Vardy     66   34
# 2      1612               Liverpool      15808    Roberto Firmino     80   37
# 3      1631          Leicester City      26150          R. Mahrez     71   36
# 4      1625         Manchester City       8325          S. Agüero     91   42
# 5      1624       Tottenham Hotspur      14911      Son Heung-Min     70   31
# 6      1625         Manchester City     245364            L. Sané     54   21
# 7      1610                 Chelsea      25707          E. Hazard     65   34
# 8      1612               Liverpool       3802  Philippe Coutinho     52   18
# 9      1624       Tottenham Hotspur       8717            H. Kane    175   74
# 10     1644                 Watford      28292        A. Doucouré     44   17
# 11     1633         West Ham United       7941       J. Hernández     28   16
# 12     1651  Brighton & Hove Albion      15526            P. Groß     41   19
# 13     1673       Huddersfield Town      38377        L. Depoitre     20   10
# 14     1646                 Burnley       9206            C. Wood     38   25
# 15     1659         AFC Bournemouth      62224          R. Fraser     31   13
# 16     1609                 Arsenal      25867      P. Aubameyang     29   18
# 17     1609                 Arsenal       3560      Nacho Monreal     21    8
# 18     1625         Manchester City     265673     Bernardo Silva     23   14
# 19     1639              Stoke City      49872         X. Shaqiri     67   29
#
#     Goals         xG         dG
# 0      32  19.111135  12.888865
# 1      20  13.382514   6.617486
# 2      15   8.471428   6.528572
# 3      12   5.913106   6.086894
# 4      21  15.345645   5.654355
# 5      12   6.737279   5.262721
# 6      10   5.141573   4.858427
# 7      12   7.474700   4.525300
# 8       7   3.439899   3.560101
# 9      29  25.735036   3.264964
# 10      7   3.753372   3.246628
# 11      8   4.803057   3.196943
# 12      7   3.872377   3.127623
# 13      6   2.948560   3.051440
# 14     10   7.108815   2.891185
# 15      5   2.213319   2.786681
# 16     10   7.224382   2.775618
# 17      5   2.233424   2.766576
# 18      6   3.313178   2.686822
# 19      8   5.321680   2.678320

# %% [markdown]
# ##### (4) 선수별 득점당 평균 xG 집계 및 정렬

# %%
#득점별 평균 xg값
#선수별 해당 골이 얼마의 xg를 보통갔는지파악
#1위인 덕배선수는 평균적으로 골의 xg값이 낮음=어려운골을 잘 넣음
player_stats['xG for goals'] = goals.groupby(['team_id', 'team_name', 'player_id', 'player_name'])['xg'].sum()
player_stats['xG per goal'] = player_stats['xG for goals'] / player_stats['Goals']
player_stats[player_stats['Goals'] >= 5].sort_values('xG per goal')[:20].reset_index()
# Out:
#     team_id               team_name  player_id        player_name  Shots  SoT  \
# 0      1625         Manchester City      38021       K. De Bruyne     91   39
# 1      1625         Manchester City     105339        Fernandinho     48   20
# 2      1639              Stoke City      49872         X. Shaqiri     67   29
# 3      1631          Leicester City      26150          R. Mahrez     71   36
# 4      1659         AFC Bournemouth      62224          R. Fraser     31   13
# 5      1651  Brighton & Hove Albion      91381       J. Izquierdo     53   16
# 6      1644                 Watford      28292        A. Doucouré     44   17
# 7      1612               Liverpool       3802  Philippe Coutinho     52   18
# 8      1611       Manchester United     397178        M. Rashford     59   21
# 9      1673       Huddersfield Town      38377        L. Depoitre     20   10
# 10     1644                 Watford      20593         R. Pereyra     34   13
# 11     1624       Tottenham Hotspur         54         C. Eriksen     97   40
# 12     1625         Manchester City     245364            L. Sané     54   21
# 13     1610                 Chelsea       8032      Marcos Alonso     59   21
# 14     1624       Tottenham Hotspur      14911      Son Heung-Min     70   31
# 15     1673       Huddersfield Town     214654          S. Mounié     49   21
# 16     1627    West Bromwich Albion       3577          S. Rondón     79   28
# 17     1609                 Arsenal       7870          A. Ramsey     52   22
# 18     1610                 Chelsea     105333            Willian     53   25
# 19     1633         West Ham United      41174         M. Lanzini     43   16
#
#     Goals        xG        dG  xG for goals  xG per goal
# 0       7  5.437935  1.562065      0.449561     0.064223
# 1       5  3.094571  1.905429      0.424643     0.084929
# 2       8  5.321680  2.678320      0.729643     0.091205
# 3      12  5.913106  6.086894      1.202199     0.100183
# 4       5  2.213319  2.786681      0.545153     0.109031
# 5       5  4.751861  0.248139      0.634217     0.126843
# 6       7  3.753372  3.246628      0.947565     0.135366
# 7       7  3.439899  3.560101      0.987696     0.141099
# 8       7  5.212934  1.787066      1.020483     0.145783
# 9       6  2.948560  3.051440      0.876203     0.146034
# 10      5  4.525451  0.474549      0.758805     0.151761
# 11     11  8.497102  2.502898      1.701890     0.154717
# 12     10  5.141573  4.858427      1.557252     0.155725
# 13      7  5.518327  1.481673      1.095941     0.156563
# 14     12  6.737279  5.262721      1.953818     0.162818
# 15      8  6.674603  1.325397      1.326163     0.165770
# 16      7  7.656276 -0.656276      1.164205     0.166315
# 17      7  6.333226  0.666774      1.168551     0.166936
# 18      6  5.146883  0.853117      1.039206     0.173201
# 19      5  4.737160  0.262840      0.876697     0.175339

# %% [markdown]
# ##### (5) 선수별 시즌 전체 xG 시각화

# %%
player_name = 'Son Heung-Min'
# player_name = 'Mohamed Salah'
# player_name = 'K. De Bruyne'

player_shots = df_shots[(df_shots['competition_name'] == 'England') & (df_shots['player_name'] == player_name)].reset_index(drop=True)
player_goals = player_shots[player_shots['tags'].apply(lambda x: 'Goal' in x)]
player_shots_failed = player_shots[player_shots['tags'].apply(lambda x: 'Goal' not in x)]

#득점으로 연결된것 = red
goal_trace = go.Scatter(
    x=104 - player_goals['x'],
    y=34 + player_goals['y'],
    name='Goal',
    mode='markers',
    marker=dict(
        color='red', size=np.sqrt(player_goals['xg']) * 50,
        symbol=player_goals['freekick'].apply(lambda x: 'square' if x == 1 else 'circle')
    )
)

#득점 실패 = darkgrey
shot_trace = go.Scatter(
    x=104 - player_shots_failed['x'],
    y=34 + player_shots_failed['y'],
    mode='markers',
    marker=dict(
        color='darkgrey', size=np.sqrt(player_shots_failed['xg']) * 50,
        symbol=player_shots_failed['freekick'].apply(lambda x: 'square' if x == 1 else 'circle')
    )
)

title = f"{player_name} - Goals: {player_shots['goal'].sum()}, xG: {round(player_shots['xg'].sum(), 3)} "
fig = go.Figure(data=[shot_trace, goal_trace], layout=get_pitch_layout(title))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d70b0d7a-8fa6-43f9-a91b-728795c4ad18" class="plotly-graph-div" style="height:600px; width:825px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d70b0d7a-8fa6-43f9-a91b-728795c4ad18")) {                    Plotly.newPlot(                        "d70b0d7a-8fa6-43f9-a91b-728795c4ad18",                        [{"marker":{"color":"darkgrey","size":[9.396812466821478,12.349032432818767,21.205299776940134,6.6714025447509515,10.939689782617478,23.623614965936795,8.224276647262684,23.485339272304138,11.132619232656776,11.132619232656776,13.227913801272148,8.28294562519253,11.426388182861785,4.187683453484759,12.854672499106162,15.470723463542022,16.971157054978057,7.274871868776953,15.193339921527778,15.470723463542022,9.347300416836166,16.726828015832034,14.009682226330114,16.262129886224912,17.732817386811078,13.135431399426375,6.344569039758752,21.36989588604377,7.3810955765375645,23.777264265367545,8.200033612348168,16.507543398026638,23.737159589153826,9.941118026787523,12.524553105035674,27.578508554009133,6.024544911454785,10.904883304119362,15.380767404856321,10.40500473722122,6.33824938359515,10.089758833715152,7.923207673364882,7.9630199170178635,15.382450077232452,17.56559182835287,16.174710071071413,10.106821250124502,16.004342028101256,20.973668333426446,4.834421352592355,12.682700509762027,11.352235239397704,11.946910431240509,18.06915482340208,13.56436267384726,16.971157054978057,9.636034648498459],"symbol":["circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle"]},"mode":"markers","x":[88.4,94.64,91.52000000000001,82.16,93.60000000000001,92.56,82.16,94.64,95.68,95.68,95.68,85.28,97.76,75.92,84.24000000000001,93.60000000000001,92.56,79.04,86.32000000000001,93.60000000000001,92.56,94.64,85.28,92.56,93.60000000000001,90.48,95.68,92.56,86.32000000000001,97.76,78.0,90.48,92.56,82.16,91.52000000000001,100.88000000000001,75.92,84.24000000000001,90.48,91.52000000000001,78.0,90.48,80.08,82.16,90.48,88.4,93.60000000000001,83.2,94.64,93.60000000000001,75.92,96.72,82.16,84.24000000000001,99.84,86.32000000000001,92.56,90.48],"y":[50.32,48.96,37.400000000000006,17.68,50.32,32.64,21.760000000000005,28.560000000000002,18.36,18.36,48.28,50.32,50.32,55.080000000000005,37.400000000000006,23.120000000000005,43.52,46.24,34.0,23.12,44.88,44.88,32.64,44.2,43.52,46.24,57.800000000000004,29.240000000000002,16.32,41.480000000000004,39.440000000000005,42.160000000000004,35.36,26.520000000000003,47.6,27.880000000000003,23.12,43.52,25.159999999999997,50.32,48.28,50.32,45.56,21.080000000000002,43.52,35.36,44.88,25.16,23.120000000000005,40.800000000000004,17.68,48.96,34.0,40.800000000000004,23.799999999999997,27.880000000000003,43.52,51.00000000000001],"type":"scatter"},{"marker":{"color":"red","size":[13.166063384404394,14.125643423249358,12.996941448152457,15.10132610954271,41.232441054736604,5.592805731912439,16.867407542167967,13.761264734756093,24.913053096293552,25.869510345323842,14.117216077372388,20.499551348329785],"symbol":["circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle"]},"mode":"markers","name":"Goal","x":[95.68,96.72,94.64,94.64,99.84,71.76,94.64,98.8,95.68,98.8,85.28,92.56],"y":[20.400000000000006,47.6,48.28,39.440000000000005,33.32,34.0,23.799999999999997,25.84000000 ...
